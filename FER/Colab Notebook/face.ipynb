# %%
# 📦 Imports
import os
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import (Conv2D, MaxPooling2D, Flatten, Dense,
                                     Dropout, BatchNormalization)
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.utils import plot_model

from zipfile import ZipFile

# 📂 Unzip
file_path = '/content/FER 2013 Dataset.zip'
with ZipFile(file_path, 'r') as zip_ref:
    zip_ref.extractall()
print("✅ Dataset extracted!")

# 📁 Directories
train_dir = '/content/train'
val_dir = '/content/test'
emotion_list = ['angry', 'disgust', 'fear', 'happy', 'sad', 'surprise', 'neutral']
img_size = 48

# 🖼️ Sample images
plt.figure(figsize=(18, 22))
for i, expression in enumerate(emotion_list):
    img_path = os.path.join(train_dir, expression, os.listdir(os.path.join(train_dir, expression))[59])
    img = load_img(img_path)
    plt.subplot(1, 7, i+1)
    plt.imshow(img)
    plt.title(expression)
    plt.axis('off')
plt.show()

# 🔁 Image Generators
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=30,
    width_shift_range=0.3,
    height_shift_range=0.3,
    shear_range=0.2,
    zoom_range=0.3,
    horizontal_flip=True,
    fill_mode='nearest'
)

val_datagen = ImageDataGenerator(rescale=1./255)

train_set = train_datagen.flow_from_directory(
    train_dir,
    target_size=(img_size, img_size),
    batch_size=64,
    class_mode='categorical',
    color_mode='grayscale'
)

val_set = val_datagen.flow_from_directory(
    val_dir,
    target_size=(img_size, img_size),
    batch_size=64,
    class_mode='categorical',
    color_mode='grayscale'
)

# 🧠 CNN Model
model = Sequential()

# Block 1
model.add(Conv2D(64, (3, 3), activation='relu', padding='same', input_shape=(48, 48, 1)))
model.add(BatchNormalization())
model.add(Conv2D(64, (3, 3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.3))

# Block 2
model.add(Conv2D(128, (3, 3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(Conv2D(128, (3, 3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.4))

# Block 3
model.add(Conv2D(256, (3, 3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(Conv2D(256, (3, 3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.5))

# Classifier
model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(7, activation='softmax'))

# 🔧 Compile
model.compile(
    optimizer=Adam(learning_rate=0.0005),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

model.summary()

# 📉 Callbacks
early_stop = EarlyStopping(monitor='val_loss', patience=49, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=1e-6)

# 🏋️ Train
history = model.fit(
    train_set,
    epochs=50,
    validation_data=val_set,
    callbacks=[early_stop, reduce_lr],
    verbose=1
)
# ✅ Final Accuracy
train_acc = history.history['accuracy'][-1] * 100
val_acc = history.history['val_accuracy'][-1] * 100
print(f"✅ Final Training Accuracy: {train_acc:.2f}%")
print(f"✅ Final Validation Accuracy: {val_acc:.2f}%")


# 📊 Plot Accuracy and Loss
fig, ax = plt.subplots(1, 2, figsize=(12, 4))

ax[0].plot(history.history['accuracy'], label='Train Acc')
ax[0].plot(history.history['val_accuracy'], label='Val Acc')
ax[0].set_title('Accuracy')
ax[0].legend()

ax[1].plot(history.history['loss'], label='Train Loss')
ax[1].plot(history.history['val_loss'], label='Val Loss')
ax[1].set_title('Loss')
ax[1].legend()

plt.show()
# Out:
# ✅ Dataset extracted!
# Found 28709 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.
# Model: "sequential_8"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_42 (Conv2D)                   │ (None, 48, 48, 64)          │             640 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_50               │ (None, 48, 48, 64)          │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_43 (Conv2D)                   │ (None, 48, 48, 64)          │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_51               │ (None, 48, 48, 64)          │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_30 (MaxPooling2D)      │ (None, 24, 24, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_44 (Dropout)                 │ (None, 24, 24, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_44 (Conv2D)                   │ (None, 24, 24, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_52               │ (None, 24, 24, 128)         │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_45 (Conv2D)                   │ (None, 24, 24, 128)         │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_53               │ (None, 24, 24, 128)         │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_31 (MaxPooling2D)      │ (None, 12, 12, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_45 (Dropout)                 │ (None, 12, 12, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_46 (Conv2D)                   │ (None, 12, 12, 256)         │         295,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_54               │ (None, 12, 12, 256)         │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_47 (Conv2D)                   │ (None, 12, 12, 256)         │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_55               │ (None, 12, 12, 256)         │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_32 (MaxPooling2D)      │ (None, 6, 6, 256)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_46 (Dropout)                 │ (None, 6, 6, 256)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_8 (Flatten)                  │ (None, 9216)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_22 (Dense)                     │ (None, 512)                 │       4,719,104 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_56               │ (None, 512)                 │           2,048 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_47 (Dropout)                 │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_23 (Dense)                     │ (None, 7)                   │           3,591 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 5,872,583 (22.40 MB)
#  Trainable params: 5,869,767 (22.39 MB)
#  Non-trainable params: 2,816 (11.00 KB)
# Epoch 1/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 49s 83ms/step - accuracy: 0.1786 - loss: 2.6561 - val_accuracy: 0.1741 - val_loss: 3.3172 - learning_rate: 5.0000e-04
# Epoch 2/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 28s 62ms/step - accuracy: 0.2145 - loss: 2.0488 - val_accuracy: 0.2718 - val_loss: 1.7660 - learning_rate: 5.0000e-04
# Epoch 3/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 28s 62ms/step - accuracy: 0.2334 - loss: 1.9113 - val_accuracy: 0.2629 - val_loss: 1.8057 - learning_rate: 5.0000e-04
# Epoch 4/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 28s 63ms/step - accuracy: 0.2434 - loss: 1.8400 - val_accuracy: 0.3126 - val_loss: 1.7020 - learning_rate: 5.0000e-04
# Epoch 5/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 28s 63ms/step - accuracy: 0.2632 - loss: 1.7898 - val_accuracy: 0.3201 - val_loss: 1.6823 - learning_rate: 5.0000e-04
# Epoch 6/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 41s 63ms/step - accuracy: 0.2882 - loss: 1.7491 - val_accuracy: 0.3349 - val_loss: 1.6268 - learning_rate: 5.0000e-04
# Epoch 7/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 28s 63ms/step - accuracy: 0.3184 - loss: 1.6885 - val_accuracy: 0.3902 - val_loss: 1.5847 - learning_rate: 5.0000e-04
# Epoch 8/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 28s 63ms/step - accuracy: 0.3620 - loss: 1.6120 - val_accuracy: 0.4415 - val_loss: 1.5502 - learning_rate: 5.0000e-04
# Epoch 9/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 28s 62ms/step - accuracy: 0.3942 - loss: 1.5497 - val_accuracy: 0.4163 - val_loss: 1.7296 - learning_rate: 5.0000e-04
# Epoch 10/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 28s 61ms/step - accuracy: 0.4221 - loss: 1.4881 - val_accuracy: 0.4847 - val_loss: 1.3392 - learning_rate: 5.0000e-04
# Epoch 11/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 27s 61ms/step - accuracy: 0.4465 - loss: 1.4312 - val_accuracy: 0.5294 - val_loss: 1.2370 - learning_rate: 5.0000e-04
# Epoch 12/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 27s 61ms/step - accuracy: 0.4739 - loss: 1.3798 - val_accuracy: 0.5430 - val_loss: 1.1978 - learning_rate: 5.0000e-04
# Epoch 13/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 28s 61ms/step - accuracy: 0.4812 - loss: 1.3616 - val_accuracy: 0.5447 - val_loss: 1.2122 - learning_rate: 5.0000e-04
# Epoch 14/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 28s 61ms/step - accuracy: 0.4959 - loss: 1.3310 - val_accuracy: 0.5536 - val_loss: 1.1756 - learning_rate: 5.0000e-04
# Epoch 15/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 27s 61ms/step - accuracy: 0.4996 - loss: 1.3130 - val_accuracy: 0.5442 - val_loss: 1.1735 - learning_rate: 5.0000e-04
# Epoch 16/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 28s 62ms/step - accuracy: 0.5068 - loss: 1.2866 - val_accuracy: 0.5632 - val_loss: 1.1473 - learning_rate: 5.0000e-04
# Epoch 17/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 28s 63ms/step - accuracy: 0.5100 - loss: 1.2809 - val_accuracy: 0.5795 - val_loss: 1.1176 - learning_rate: 5.0000e-04
# Epoch 18/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 28s 61ms/step - accuracy: 0.5261 - loss: 1.2502 - val_accuracy: 0.5805 - val_loss: 1.1118 - learning_rate: 5.0000e-04
# Epoch 19/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 28s 62ms/step - accuracy: 0.5274 - loss: 1.2435 - val_accuracy: 0.5830 - val_loss: 1.1012 - learning_rate: 5.0000e-04
# Epoch 20/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 28s 61ms/step - accuracy: 0.5338 - loss: 1.2284 - val_accuracy: 0.5709 - val_loss: 1.1472 - learning_rate: 5.0000e-04
# Epoch 21/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 28s 62ms/step - accuracy: 0.5297 - loss: 1.2218 - val_accuracy: 0.5751 - val_loss: 1.1257 - learning_rate: 5.0000e-04
# Epoch 22/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 40s 61ms/step - accuracy: 0.5403 - loss: 1.2106 - val_accuracy: 0.5878 - val_loss: 1.0837 - learning_rate: 5.0000e-04
# Epoch 23/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 28s 61ms/step - accuracy: 0.5492 - loss: 1.1967 - val_accuracy: 0.5809 - val_loss: 1.1024 - learning_rate: 5.0000e-04
# Epoch 24/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 27s 61ms/step - accuracy: 0.5439 - loss: 1.1949 - val_accuracy: 0.6037 - val_loss: 1.0537 - learning_rate: 5.0000e-04
# Epoch 25/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 28s 63ms/step - accuracy: 0.5532 - loss: 1.1855 - val_accuracy: 0.6055 - val_loss: 1.0665 - learning_rate: 5.0000e-04
# Epoch 26/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 27s 61ms/step - accuracy: 0.5601 - loss: 1.1714 - val_accuracy: 0.5910 - val_loss: 1.1043 - learning_rate: 5.0000e-04
# Epoch 27/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 41s 62ms/step - accuracy: 0.5593 - loss: 1.1589 - val_accuracy: 0.5977 - val_loss: 1.0710 - learning_rate: 5.0000e-04
# Epoch 28/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 29s 64ms/step - accuracy: 0.5663 - loss: 1.1571 - val_accuracy: 0.6035 - val_loss: 1.0477 - learning_rate: 5.0000e-04
# Epoch 29/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 29s 64ms/step - accuracy: 0.5642 - loss: 1.1534 - val_accuracy: 0.5958 - val_loss: 1.0792 - learning_rate: 5.0000e-04
# Epoch 30/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 28s 62ms/step - accuracy: 0.5611 - loss: 1.1557 - val_accuracy: 0.6141 - val_loss: 1.0184 - learning_rate: 5.0000e-04
# Epoch 31/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 29s 64ms/step - accuracy: 0.5652 - loss: 1.1432 - val_accuracy: 0.6262 - val_loss: 0.9945 - learning_rate: 5.0000e-04
# Epoch 32/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 28s 62ms/step - accuracy: 0.5748 - loss: 1.1329 - val_accuracy: 0.6094 - val_loss: 1.0463 - learning_rate: 5.0000e-04
# Epoch 33/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 27s 61ms/step - accuracy: 0.5740 - loss: 1.1325 - val_accuracy: 0.6145 - val_loss: 1.0297 - learning_rate: 5.0000e-04
# Epoch 34/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 29s 64ms/step - accuracy: 0.5751 - loss: 1.1264 - val_accuracy: 0.6233 - val_loss: 0.9954 - learning_rate: 5.0000e-04
# Epoch 35/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 30s 66ms/step - accuracy: 0.5698 - loss: 1.1327 - val_accuracy: 0.6078 - val_loss: 1.0332 - learning_rate: 5.0000e-04
# Epoch 36/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 29s 64ms/step - accuracy: 0.5787 - loss: 1.1123 - val_accuracy: 0.6159 - val_loss: 1.0244 - learning_rate: 5.0000e-04
# Epoch 37/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 28s 63ms/step - accuracy: 0.5859 - loss: 1.0951 - val_accuracy: 0.6379 - val_loss: 0.9734 - learning_rate: 1.0000e-04
# Epoch 38/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 29s 64ms/step - accuracy: 0.5988 - loss: 1.0688 - val_accuracy: 0.6393 - val_loss: 0.9667 - learning_rate: 1.0000e-04
# Epoch 39/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 41s 63ms/step - accuracy: 0.5963 - loss: 1.0613 - val_accuracy: 0.6427 - val_loss: 0.9648 - learning_rate: 1.0000e-04
# Epoch 40/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 28s 63ms/step - accuracy: 0.5993 - loss: 1.0689 - val_accuracy: 0.6383 - val_loss: 0.9644 - learning_rate: 1.0000e-04
# Epoch 41/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 28s 63ms/step - accuracy: 0.6013 - loss: 1.0510 - val_accuracy: 0.6403 - val_loss: 0.9648 - learning_rate: 1.0000e-04
# Epoch 42/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 41s 64ms/step - accuracy: 0.5960 - loss: 1.0613 - val_accuracy: 0.6463 - val_loss: 0.9595 - learning_rate: 1.0000e-04
# Epoch 43/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 28s 63ms/step - accuracy: 0.6038 - loss: 1.0637 - val_accuracy: 0.6436 - val_loss: 0.9592 - learning_rate: 1.0000e-04
# Epoch 44/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 28s 62ms/step - accuracy: 0.6072 - loss: 1.0426 - val_accuracy: 0.6436 - val_loss: 0.9542 - learning_rate: 1.0000e-04
# Epoch 45/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 28s 63ms/step - accuracy: 0.6112 - loss: 1.0420 - val_accuracy: 0.6457 - val_loss: 0.9528 - learning_rate: 1.0000e-04
# Epoch 46/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 27s 61ms/step - accuracy: 0.6029 - loss: 1.0495 - val_accuracy: 0.6413 - val_loss: 0.9630 - learning_rate: 1.0000e-04
# Epoch 47/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 28s 61ms/step - accuracy: 0.6073 - loss: 1.0370 - val_accuracy: 0.6400 - val_loss: 0.9662 - learning_rate: 1.0000e-04
# Epoch 48/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 28s 61ms/step - accuracy: 0.6101 - loss: 1.0421 - val_accuracy: 0.6450 - val_loss: 0.9556 - learning_rate: 1.0000e-04
# Epoch 49/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 28s 63ms/step - accuracy: 0.6071 - loss: 1.0441 - val_accuracy: 0.6447 - val_loss: 0.9525 - learning_rate: 1.0000e-04
# Epoch 50/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 28s 61ms/step - accuracy: 0.6123 - loss: 1.0316 - val_accuracy: 0.6516 - val_loss: 0.9524 - learning_rate: 1.0000e-04
# ✅ Final Training Accuracy: 61.42%
# ✅ Final Validation Accuracy: 65.16%

# %%
import numpy as np
import matplotlib.pyplot as plt
import itertools
from sklearn.metrics import confusion_matrix
from tensorflow.keras.preprocessing import image

# Predict on validation set
predictions = model.predict(val_set)
y_pred = [np.argmax(p) for p in predictions]
y_test = val_set.classes
class_names = list(val_set.class_indices.keys())

# Confusion matrix plotting function
def plot_confusion_matrix(cm, classes, title='Confusion Matrix', cmap=plt.cm.Blues):
    cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]  # Normalize
    plt.figure(figsize=(12, 6), dpi=120)
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    ticks = np.arange(len(classes))
    plt.xticks(ticks, classes, rotation=45)
    plt.yticks(ticks, classes)

    fmt = '.2f'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 ha="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()
    plt.show()

# Confusion matrix
cnf_matrix = confusion_matrix(y_test, y_pred)
plot_confusion_matrix(cnf_matrix, classes=class_names)

# Accuracy and Loss Plots
fig, ax = plt.subplots(1, 2, figsize=(12, 4))
ax[0].plot(history.history['accuracy'], label='Train')
ax[0].plot(history.history['val_accuracy'], label='Validation')
ax[0].set_title('Accuracy')
ax[0].legend()

ax[1].plot(history.history['loss'], label='Train')
ax[1].plot(history.history['val_loss'], label='Validation')
ax[1].set_title('Loss')
ax[1].legend()
plt.show()

# Predict a single image
label_dict = {0:'Angry',1:'Disgust',2:'Fear',3:'Happy',4:'Neutral',5:'Sad',6:'Surprise'}
img_path = "/content/test/angry/PrivateTest_10131363.jpg"
img = image.load_img(img_path, target_size=(48, 48), color_mode="grayscale")
img_array = np.array(img)
plt.imshow(img_array, cmap='gray')
print("Image shape:", img_array.shape)

# Preprocess and predict
img_array = img_array.reshape(1, 48, 48, 1)
result = model.predict(img_array)[0]
print("Raw prediction:", result)

predicted_class = np.argmax(result)
print("Predicted label:", label_dict[predicted_class])

# Save model and weights
model.save('model_78.h5')
model.save_weights('model_weights_78.weights.h5')
# Out:
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step
# Image shape: (48, 48)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 598ms/step
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Raw prediction: [1. 0. 0. 0. 0. 0. 0.]
# Predicted label: Angry
